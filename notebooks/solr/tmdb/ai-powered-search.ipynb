# %%
import requests
import json

from ltr.client.solr_client import SolrClient

client = SolrClient()
host = client.get_host()

# %% [markdown]
# ## Download, reindex...
#
# 1. Download the corpus & judgments
# 2. Rebuild the index from the tmdb solr config
# 3. Reindex movies loaded from the corpus

# %%
from ltr import download

tmdb_corpus='http://es-learn-to-rank.labs.o19s.com/tmdb_ai_pow_search.json'
judgments='http://es-learn-to-rank.labs.o19s.com/title_judgments_binary.txt'
download([tmdb_corpus, judgments], dest='data/');
# Out:
# data/tmdb_ai_pow_search.json already exists
# data/title_judgments_binary.txt already exists

# %%
from ltr.index import rebuild
from ltr.helpers.movies import indexable_movies
movies=indexable_movies(movies='data/tmdb_ai_pow_search.json')
rebuild(client, index='tmdb', doc_src=movies)
# Out:
# Reconfig from disk...
# Deleted index tmdb [Status: 400]
# {
#   "responseHeader":{
#     "status":400,
#     "QTime":16},
#   "error":{
#     "metadata":[
#       "error-class","org.apache.solr.common.SolrException",
#       "root-error-class","org.apache.solr.common.SolrException"],
#     "msg":"Cannot unload non-existent core [tmdb]",
#     "code":400}}
#
# Created index tmdb [Status: 200]
# Reindexing...
# Indexed 0 movies (last The Elusive Corporal)
# Indexed 100 movies (last Mom and Dad)
# Indexed 200 movies (last The Belle of New York)
# Indexed 300 movies (last The Song of Bernadette)
# Indexed 400 movies (last That Funny Feeling)
# Indexed 500 movies (last Gold Diggers of 1935)
# Indexed 600 movies (last WWE WrestleMania IV)
# Indexed 700 movies (last The Trespasser)
# Indexed 800 movies (last WWE: Hollywood Hulk Hogan - Hulk Still Rules)
# Indexed 900 movies (last Bomba On Panther Island)
# Indexed 1000 movies (last Redeemer)
# Indexed 1100 movies (last Convict Cowboy)
# Indexed 1200 movies (last The VelociPastor)
# Indexed 1300 movies (last Mannaggia alla miseria!)
# Indexed 1400 movies (last They Raid by Night)
# Indexed 1500 movies (last War Dogs)
# Indexed 1600 movies (last Uncut)
# Indexed 1700 movies (last There Goes My Baby)
# Indexed 1800 movies (last She Devil)
# Indexed 1900 movies (last Tougher Than Leather)
# Indexed 2000 movies (last To the Beat! Back 2 School)
# Indexed 2100 movies (last The Dark Corner)
# Indexed 2200 movies (last 49th Parallel)
# Indexed 2300 movies (last Target Earth)
# Indexed 2400 movies (last Nuit noire, 17 octobre 1961)
# Indexed 2500 movies (last The Formula)
# Indexed 2600 movies (last The Ascent of Money)
# Indexed 2700 movies (last Jane Wants a Boyfriend)
# Indexed 2800 movies (last Redfern Now: Promise Me)
# Indexed 2900 movies (last The Blessed Ones)
# Indexed 3000 movies (last Tiger Orange)
# Indexed 3100 movies (last Irene)
# Indexed 3200 movies (last China Doll)
# Indexed 3300 movies (last Brutal)
# Indexed 3400 movies (last And While We Were Here)
# Indexed 3500 movies (last Take Me Somewhere Nice)
# Indexed 3600 movies (last Tigertail)
# Indexed 3700 movies (last Jack the Giant Slayer)
# Indexed 3800 movies (last Air Hostess)
# Indexed 3900 movies (last Swayamkrushi)
# Indexed 4000 movies (last Death Collector)
# Indexed 4100 movies (last Top Gear: The Perfect Road Trip 2)
# Indexed 4200 movies (last The Ball)
# Indexed 4300 movies (last Quality Problems)
# Indexed 4400 movies (last The Sunchaser)
# Indexed 4500 movies (last Charlie Chan on Broadway)
# Indexed 4600 movies (last Madison)
# Indexed 4700 movies (last Sorcerer)
# Indexed 4800 movies (last Color Me Blood Red)
# Indexed 4900 movies (last The Invisible Woman)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 5000 movies (last Spoiler)
# Indexed 5100 movies (last The Dog Who Saved Christmas)
# Indexed 5200 movies (last A Flag Without a Country)
# Indexed 5300 movies (last The Lessee)
# Indexed 5400 movies (last Call Me Claus)
# Indexed 5500 movies (last Mulberry Street)
# Indexed 5600 movies (last The Wild Parrots of Telegraph Hill)
# Indexed 5700 movies (last Anchors Aweigh)
# Indexed 5800 movies (last Riley the Cop)
# Indexed 5900 movies (last Rob Delaney: Live at the Bowery Ballroom)
# Indexed 6000 movies (last See You in the Morning)
# Indexed 6100 movies (last Banjo)
# Indexed 6200 movies (last Guns N' Roses Paris 92)
# Indexed 6300 movies (last The Resurrection of Zachary Wheeler)
# Indexed 6400 movies (last Reel)
# Indexed 6500 movies (last Freak Out)
# Indexed 6600 movies (last At Long Last Love)
# Indexed 6700 movies (last Goodland)
# Indexed 6800 movies (last 42 Grams)
# Indexed 6900 movies (last Gambling Lady)
# Indexed 7000 movies (last Zachariah)
# Indexed 7100 movies (last The Guys)
# Indexed 7200 movies (last Dakota Incident)
# Indexed 7300 movies (last It's All True)
# Indexed 7400 movies (last 3 Godfathers)
# Indexed 7500 movies (last Don't Touch My Daughter)
# Indexed 7600 movies (last Fists of Iron)
# Indexed 7700 movies (last The Nutty Professor)
# Indexed 7800 movies (last Mighty Joe Young)
# Indexed 7900 movies (last Portrait in Black)
# Indexed 8000 movies (last Hitler: Unknown soldier)
# Indexed 8100 movies (last Bravetown)
# Indexed 8200 movies (last 8 Days to Premiere)
# Indexed 8300 movies (last Cop Car)
# Indexed 8400 movies (last These Thousand Hills)
# Indexed 8500 movies (last Above and Beyond)
# Indexed 8600 movies (last Torvill & Dean)
# Indexed 8700 movies (last The Dunes)
# Indexed 8800 movies (last Martyrs)
# Indexed 8900 movies (last Shopworn)
# Indexed 9000 movies (last Quartet)
# Indexed 9100 movies (last Daughters Courageous)
# Indexed 9200 movies (last Rosemont)
# Indexed 9300 movies (last Heartland)
# Indexed 9400 movies (last The Good Student)
# Indexed 9500 movies (last The Boys from Brazil)
# Indexed 9600 movies (last The First of the Few)
# Indexed 9700 movies (last Cheats)
# Indexed 9800 movies (last Woodshock)
# Indexed 9900 movies (last Strictly Dynamite)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 10000 movies (last The Hammer)
# Indexed 10100 movies (last Deadly Game)
# Indexed 10200 movies (last The Legend of Lobo)
# Indexed 10300 movies (last Mountain Rest)
# Indexed 10400 movies (last Vicky Cristina Barcelona)
# Indexed 10500 movies (last Trancers)
# Indexed 10600 movies (last The Wrong Bed: Naked Pursuit)
# Indexed 10700 movies (last The Favor)
# Indexed 10800 movies (last Slaughter Trail)
# Indexed 10900 movies (last 38 Special: Live at Sturgis)
# Indexed 11000 movies (last Gaslit)
# Indexed 11100 movies (last Time Toys)
# Indexed 11200 movies (last Tracks)
# Indexed 11300 movies (last Loving Vincent: The Impossible Dream)
# Indexed 11400 movies (last Alien Predators)
# Indexed 11500 movies (last Hard to Hold)
# Indexed 11600 movies (last Cal)
# Indexed 11700 movies (last Road Train)
# Indexed 11800 movies (last The Vanquisher)
# Indexed 11900 movies (last You're a Big Boy Now)
# Indexed 12000 movies (last Palm Springs Weekend)
# Indexed 12100 movies (last Mr. Bones 2: Back from the Past)
# Indexed 12200 movies (last Strange Impersonation)
# Indexed 12300 movies (last Body Count)
# Indexed 12400 movies (last The Children's Hour)
# Indexed 12500 movies (last Invaders from Mars)
# Indexed 12600 movies (last Whore)
# Indexed 12700 movies (last Lest We Forget)
# Indexed 12800 movies (last Assassin of Youth)
# Indexed 12900 movies (last They Paid with Bullets: Chicago 1929)
# Indexed 13000 movies (last Paper Angels)
# Indexed 13100 movies (last I Am Here....Now)
# Indexed 13200 movies (last 30 Girls 30 Days)
# Indexed 13300 movies (last Green Ice)
# Indexed 13400 movies (last The Perfect Human Diet)
# Indexed 13500 movies (last When the Garden Was Eden)
# Indexed 13600 movies (last A Deadly View)
# Indexed 13700 movies (last Big Time)
# Indexed 13800 movies (last Only the Dead)
# Indexed 13900 movies (last Battle Star Wars)
# Indexed 14000 movies (last Arrow In The Dust)
# Indexed 14100 movies (last The Women of Brewster Place)
# Indexed 14200 movies (last Babysitter's Black Book)
# Indexed 14300 movies (last Texas Terror Tales)
# Indexed 14400 movies (last Stranger in the House)
# Indexed 14500 movies (last I Don't Feel at Home in This World Anymore: Film, Stories & Images from the Mississippi Records and Alan Lomax Archive)
# Indexed 14600 movies (last Nurse Edith Cavell)
# Indexed 14700 movies (last Apollo Goes on Holiday)
# Indexed 14800 movies (last Crip Camp: A Disability Revolution)
# Indexed 14900 movies (last An Invisible Sign)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 15000 movies (last Horowitz in Moscow)
# Indexed 15100 movies (last Rough Cut)
# Indexed 15200 movies (last A Cross the Universe)
# Indexed 15300 movies (last Ram Balaram)
# Indexed 15400 movies (last The Lost Okoroshi)
# Indexed 15500 movies (last Above Majestic)
# Indexed 15600 movies (last Taxi!)
# Indexed 15700 movies (last Pepe)
# Indexed 15800 movies (last Confession)
# Indexed 15900 movies (last In Her Skin)
# Indexed 16000 movies (last My Blue Heaven)
# Indexed 16100 movies (last The Strawberry Blonde)
# Indexed 16200 movies (last 'Twas the Night Before Bumpy)
# Indexed 16300 movies (last Autumn Blood)
# Indexed 16400 movies (last Wedding March 2: Resorting to Love)
# Indexed 16500 movies (last Julia)
# Indexed 16600 movies (last The Goldfinch)
# Indexed 16700 movies (last Heartaches)
# Indexed 16800 movies (last Knight of the Plains)
# Indexed 16900 movies (last Gallavants)
# Indexed 17000 movies (last A Place Called Home)
# Indexed 17100 movies (last The Age of Consequences)
# Indexed 17200 movies (last Christmas in Wonderland)
# Indexed 17300 movies (last Hoop Dreams)
# Indexed 17400 movies (last From Beyond)
# Indexed 17500 movies (last The Nine Lives of Fritz the Cat)
# Indexed 17600 movies (last Joe Kidd)
# Indexed 17700 movies (last The Heart Is a Lonely Hunter)
# Indexed 17800 movies (last Deadly Sins)
# Indexed 17900 movies (last TwentyFourSeven)
# Indexed 18000 movies (last Carry On Teacher)
# Indexed 18100 movies (last 24 Hours in London)
# Indexed 18200 movies (last Captains of the Clouds)
# Indexed 18300 movies (last The Rise & Fall of a White Collar Hooligan)
# Indexed 18400 movies (last Peeper)
# Indexed 18500 movies (last Growing Up Smith)
# Indexed 18600 movies (last Executive Power)
# Indexed 18700 movies (last WWE Hall Of Fame 2014)
# Indexed 18800 movies (last Wax)
# Indexed 18900 movies (last American Idiots)
# Indexed 19000 movies (last The House of Screaming Death)
# Indexed 19100 movies (last A Modern Hero)
# Indexed 19200 movies (last Thou Shalt Not Kill... Except)
# Indexed 19300 movies (last KylieFever2002: Live in Manchester)
# Indexed 19400 movies (last The Shadow of the Eagle)
# Indexed 19500 movies (last Seven Sinners)
# Indexed 19600 movies (last Snow)
# Indexed 19700 movies (last Fog Over Frisco)
# Indexed 19800 movies (last The Pilgrim's Progress)
# Indexed 19900 movies (last Disobedience)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 20000 movies (last Dreammaster: The Erotic Invader)
# Indexed 20100 movies (last Spider-Man: Into the Spider-Verse)
# Indexed 20200 movies (last Hell's Heroes)
# Indexed 20300 movies (last Dying of the Light)
# Indexed 20400 movies (last Midnight Sun)
# Indexed 20500 movies (last The Angel Levine)
# Indexed 20600 movies (last The Gamechangers)
# Indexed 20700 movies (last The Bray Road Beast)
# Indexed 20800 movies (last The Escort)
# Indexed 20900 movies (last Darna vs. The Planet Women)
# Indexed 21000 movies (last Big Easy Express)
# Indexed 21100 movies (last In Security)
# Indexed 21200 movies (last Almost There)
# Indexed 21300 movies (last Mannequin)
# Indexed 21400 movies (last Charlie Chan at the Race Track)
# Indexed 21500 movies (last The Return of the Whistler)
# Indexed 21600 movies (last Doctor Detroit)
# Indexed 21700 movies (last Lil' Pimp)
# Indexed 21800 movies (last Captain Horatio Hornblower R.N.)
# Indexed 21900 movies (last Mad Mom)
# Indexed 22000 movies (last Mean Girls 2)
# Indexed 22100 movies (last Murder Rooms: Mysteries of the Real Sherlock Holmes)
# Indexed 22200 movies (last The Brotherhood of Justice)
# Indexed 22300 movies (last Plan 10 from Outer Space)
# Indexed 22400 movies (last Prom Night III: The Last Kiss)
# Indexed 22500 movies (last Woman on the Run)
# Indexed 22600 movies (last Dagli Appennini alle Ande)
# Indexed 22700 movies (last Brothers of the Wind)
# Indexed 22800 movies (last John Denver's Christmas in Aspen)
# Indexed 22900 movies (last The Human Scale)
# Indexed 23000 movies (last Open Road)
# Indexed 23100 movies (last Being Canadian)
# Indexed 23200 movies (last One Winter Proposal)
# Indexed 23300 movies (last In Broad Daylight)
# Indexed 23400 movies (last Emma's Wish)
# Indexed 23500 movies (last Godzilla Battle Royale)
# Indexed 23600 movies (last Niko: Journey to Magika)
# Indexed 23700 movies (last The Confirmation)
# Indexed 23800 movies (last Mickey Mouse Clubhouse: Mickey's Treat)
# Indexed 23900 movies (last Journey to Promethea)
# Indexed 24000 movies (last Mindwalk)
# Indexed 24100 movies (last Fall of Hyperion)
# Indexed 24200 movies (last Dark Planet)
# Indexed 24300 movies (last Under the Wire)
# Indexed 24400 movies (last Suspiria)
# Indexed 24500 movies (last The Judge and Jake Wyler)
# Indexed 24600 movies (last The Death and Return of Superman)
# Indexed 24700 movies (last Law and Order)
# Indexed 24800 movies (last St. Louis Blues)
# Indexed 24900 movies (last I Was an American Spy)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 25000 movies (last Polis Evo 2)
# Indexed 25100 movies (last Kenny)
# Indexed 25200 movies (last Certain Fury)
# Indexed 25300 movies (last Esther)
# Indexed 25400 movies (last Fracture)
# Indexed 25500 movies (last Horse Sense)
# Indexed 25600 movies (last Todas las mujeres)
# Indexed 25700 movies (last Into the Abyss)
# Indexed 25800 movies (last Fist 2 Fist)
# Indexed 25900 movies (last Bloodlust Zombies)
# Indexed 26000 movies (last Walking Tall: The Payback)
# Indexed 26100 movies (last The Golden Boys)
# Indexed 26200 movies (last Alfie)
# Indexed 26300 movies (last Framed for Murder)
# Indexed 26400 movies (last Bourek)
# Indexed 26500 movies (last The Face of an Angel)
# Indexed 26600 movies (last Garzey's Wing)
# Indexed 26700 movies (last Mute)
# Indexed 26800 movies (last Sick Boy)
# Indexed 26900 movies (last Wonder Bar)
# Indexed 27000 movies (last The Horror of Frankenstein)
# Indexed 27100 movies (last Frankie and Johnny)
# Indexed 27200 movies (last Daisy Winters)
# Indexed 27300 movies (last Becoming Colette)
# Indexed 27400 movies (last Dante's Inferno)
# Indexed 27500 movies (last The Next Voice You Hear...)
# Indexed 27600 movies (last Riverworld)
# Indexed 27700 movies (last Harry in Your Pocket)
# Indexed 27800 movies (last Maz Jobrani: Brown and Friendly)
# Indexed 27900 movies (last Hot Tamale)
# Indexed 28000 movies (last Police Academy 2: Their First Assignment)
# Indexed 28100 movies (last The Ides of March)
# Indexed 28200 movies (last 28 Days)
# Indexed 28300 movies (last Barbershop)
# Indexed 28400 movies (last Dr. T & the Women)
# Indexed 28500 movies (last Heaven's Gate)
# Indexed 28600 movies (last Mystery Woman: At First Sight)
# Indexed 28700 movies (last 6 Bullets)
# Indexed 28800 movies (last Running Delilah)
# Indexed 28900 movies (last There Goes the Groom)
# Indexed 29000 movies (last Touched by Auschwitz)
# Indexed 29100 movies (last Stalked by My Doctor: The Return)
# Indexed 29200 movies (last Don't Let the Night End)
# Indexed 29300 movies (last Prescription for Danger)
# Indexed 29400 movies (last Sasheer Zamata: Pizza Mind)
# Indexed 29500 movies (last Unleashing Mr. Darcy)
# Indexed 29600 movies (last Key Witness)
# Indexed 29700 movies (last Marines)
# Indexed 29800 movies (last The Insomniac on the Bridge)
# Indexed 29900 movies (last A Perfect Day)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 30000 movies (last The Invitation)
# Indexed 30100 movies (last The Day of Two Noons)
# Indexed 30200 movies (last Ghost Legend)
# Indexed 30300 movies (last I'll Be Seeing You)
# Indexed 30400 movies (last Don Quixote (Kirov Ballet))
# Indexed 30500 movies (last Dead Fish)
# Indexed 30600 movies (last Leprechaun 3)
# Indexed 30700 movies (last Bob Funk)
# Indexed 30800 movies (last Comedian)
# Indexed 30900 movies (last Churchill)
# Indexed 31000 movies (last Good Dame)
# Indexed 31100 movies (last Rohmer in Paris)
# Indexed 31200 movies (last Happy Ever After)
# Indexed 31300 movies (last Prowler)
# Indexed 31400 movies (last Olympic Dreams)
# Indexed 31500 movies (last Central Park)
# Indexed 31600 movies (last Inhabit: A Permaculture Perspective)
# Indexed 31700 movies (last Haunting of Cellblock 11)
# Indexed 31800 movies (last Unfriended)
# Indexed 31900 movies (last Nocturne)
# Indexed 32000 movies (last Catch the Heat)
# Indexed 32100 movies (last The Millionaire Tour)
# Indexed 32200 movies (last Cabal)
# Indexed 32300 movies (last Cops & Robbersons)
# Indexed 32400 movies (last H2O Extreme)
# Indexed 32500 movies (last Sorority Row)
# Indexed 32600 movies (last A Christmas Visitor)
# Indexed 32700 movies (last Delusion)
# Indexed 32800 movies (last Bébé's Kids)
# Indexed 32900 movies (last Bratz: Genie Magic)
# Indexed 33000 movies (last Mr. Denning Drives North)
# Indexed 33100 movies (last Story of a Bad Boy)
# Indexed 33200 movies (last Big Time)
# Indexed 33300 movies (last 13)
# Indexed 33400 movies (last Silverchair: Across the Great Divide)
# Indexed 33500 movies (last L.A. Streetfighters)
# Indexed 33600 movies (last Checkpoint)
# Indexed 33700 movies (last The Thanksgiving Promise)
# Indexed 33800 movies (last American Folk)
# Indexed 33900 movies (last New Eden)
# Indexed 34000 movies (last Secret Obsession)
# Indexed 34100 movies (last Killer Vacation)
# Indexed 34200 movies (last Shanghai Belle)
# Indexed 34300 movies (last Small Time)
# Indexed 34400 movies (last The Switch or How to Alter Your Ego)
# Indexed 34500 movies (last All the Right Moves)
# Indexed 34600 movies (last Crazy)
# Indexed 34700 movies (last Royal Wedding)
# Indexed 34800 movies (last Red Pearls of Love)
# Indexed 34900 movies (last The Dirty Game)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 35000 movies (last Wicked Spring)
# Indexed 35100 movies (last Bing Crosby: Rediscovered)
# Indexed 35200 movies (last Donne di mafia)
# Indexed 35300 movies (last All Through the Night)
# Indexed 35400 movies (last The Strange Mr. Gregory)
# Indexed 35500 movies (last Christopher Strong)
# Indexed 35600 movies (last Running on Empty)
# Indexed 35700 movies (last Mr. Freedom)
# Indexed 35800 movies (last Muscle Beach Party)
# Indexed 35900 movies (last Extraordinary Measures)
# Indexed 36000 movies (last Steel Dawn)
# Indexed 36100 movies (last Legion of Brothers)
# Indexed 36200 movies (last Garage Sale Mystery: The Art of Murder)
# Indexed 36300 movies (last Cry in the Wild: The Taking of Peggy Ann)
# Indexed 36400 movies (last One of My Wives Is Missing)
# Indexed 36500 movies (last I Used to Be Darker)
# Indexed 36600 movies (last A Girl Thing)
# Indexed 36700 movies (last Public Enemy's Wife)
# Indexed 36800 movies (last The Medici: Makers of Modern Art)
# Indexed 36900 movies (last Cracking the Shakespeare Code)
# Indexed 37000 movies (last Against the Law)
# Indexed 37100 movies (last Fancy Pants)
# Indexed 37200 movies (last Tarzan and the Amazons)
# Indexed 37300 movies (last Going Places)
# Indexed 37400 movies (last Paid in Full)
# Indexed 37500 movies (last A Daughter's Deception)
# Indexed 37600 movies (last Darklands)
# Indexed 37700 movies (last The Pusher)
# Indexed 37800 movies (last Telling Lies in America)
# Indexed 37900 movies (last Jake Squared)
# Indexed 38000 movies (last Mirch Masala)
# Indexed 38100 movies (last Aliens vs. Titanic)
# Indexed 38200 movies (last Kiss of the Dragon)
# Indexed 38300 movies (last Harley Davidson and the Marlboro Man)
# Indexed 38400 movies (last Michael)
# Indexed 38500 movies (last Snowbound: The Jim and Jennifer Stolpa Story)
# Indexed 38600 movies (last Mine Games)
# Indexed 38700 movies (last The Knot)
# Indexed 38800 movies (last Can You Hear Me Thinking?)
# Indexed 38900 movies (last Zombex)
# Indexed 39000 movies (last The Good Lie)
# Indexed 39100 movies (last Decadence and Downfall: The Shah of Iran's Ultimate Party)
# Indexed 39200 movies (last Hide and Seek)
# Indexed 39300 movies (last Mystery Train)
# Indexed 39400 movies (last Manhunter)
# Indexed 39500 movies (last DeepStar Six)
# Indexed 39600 movies (last Animal Farm)
# Indexed 39700 movies (last The Hatching)
# Indexed 39800 movies (last The Space Between Us)
# Indexed 39900 movies (last London 2012: Gymnastics - Going for the Gold)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 40000 movies (last The Accountant of Auschwitz)
# Indexed 40100 movies (last The Photograph)
# Indexed 40200 movies (last Banana Split)
# Indexed 40300 movies (last Rites of Blood)
# Indexed 40400 movies (last Rosie)
# Indexed 40500 movies (last The Man with the Iron Fists)
# Indexed 40600 movies (last A Wish Come True)
# Indexed 40700 movies (last Sudden Death)
# Indexed 40800 movies (last Never Trust a Gambler)
# Indexed 40900 movies (last Othello)
# Indexed 41000 movies (last Rusty: A Dog's Tale)
# Indexed 41100 movies (last Kingpin)
# Indexed 41200 movies (last The Two Mr. Kissels)
# Indexed 41300 movies (last Surrounded)
# Indexed 41400 movies (last Now & Later)
# Indexed 41500 movies (last Dead Heat on a Merry-Go-Round)
# Indexed 41600 movies (last AS:VS Back in Business)
# Indexed 41700 movies (last Femme Fatale)
# Indexed 41800 movies (last The Full Monty)
# Indexed 41900 movies (last The Dentist)
# Indexed 42000 movies (last Home Alone 3)
# Indexed 42100 movies (last To Live and Die in L.A.)
# Indexed 42200 movies (last The Great Mouse Detective)
# Indexed 42300 movies (last Guilty of Treason)
# Indexed 42400 movies (last Affairs of a Gentleman)
# Indexed 42500 movies (last A Hitman in London)
# Indexed 42600 movies (last Qualified)
# Indexed 42700 movies (last Under the Pampas Moon)
# Indexed 42800 movies (last Underwater)
# Indexed 42900 movies (last A Great Wall)
# Indexed 43000 movies (last A Coffin for the Bride)
# Indexed 43100 movies (last WWE Armageddon 2007)
# Indexed 43200 movies (last Mo)
# Indexed 43300 movies (last Love and Death on Long Island)
# Indexed 43400 movies (last L'école buissonnière)
# Indexed 43500 movies (last Wrath of the Titans)
# Indexed 43600 movies (last Body Chemistry 4: Full Exposure)
# Indexed 43700 movies (last George Carlin: Doin' it Again)
# Indexed 43800 movies (last New World Disorder 9: Never Enough)
# Indexed 43900 movies (last The Alien Dead)
# Indexed 44000 movies (last My Date with Drew)
# Indexed 44100 movies (last Bunny and the Bull)
# Indexed 44200 movies (last Dirty Laundry)
# Indexed 44300 movies (last A Royal Christmas Ball)
# Indexed 44400 movies (last Doctor, You've Got to Be Kidding!)
# Indexed 44500 movies (last Brute Corps)
# Indexed 44600 movies (last Assault Platoon)
# Indexed 44700 movies (last alshuwq Palace)
# Indexed 44800 movies (last Echo in the Canyon)
# Indexed 44900 movies (last Alvin and the Chipmunks: Christmas with The Chipmunks)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 45000 movies (last Vanity)
# Indexed 45100 movies (last Descendants 2)
# Indexed 45200 movies (last Grave Encounters 2)
# Indexed 45300 movies (last FBI Girl)
# Indexed 45400 movies (last Three Bedrooms, One Corpse: An Aurora Teagarden Mystery)
# Indexed 45500 movies (last How to Lose Friends & Alienate People)
# Indexed 45600 movies (last Harold & Kumar Escape from Guantanamo Bay)
# Indexed 45700 movies (last Free Enterprise)
# Indexed 45800 movies (last Imposture)
# Indexed 45900 movies (last Death Wish)
# Indexed 46000 movies (last Go for It!)
# Indexed 46100 movies (last Burn Notice: The Fall of Sam Axe)
# Indexed 46200 movies (last The Last Patrol)
# Indexed 46300 movies (last China Seas)
# Indexed 46400 movies (last Model Behavior)
# Indexed 46500 movies (last The Petty Girl)
# Indexed 46600 movies (last Mars Attacks!)
# Indexed 46700 movies (last Syriana)
# Indexed 46800 movies (last The Chronicles of Narnia: The Lion, the Witch and the Wardrobe)
# Indexed 46900 movies (last To Kill a Mockingbird)
# Indexed 47000 movies (last Face/Off)
# Indexed 47100 movies (last The Flintstones in Viva Rock Vegas)
# Indexed 47200 movies (last Garage Sale Mystery: Murder By Text)
# Indexed 47300 movies (last Stratton)
# Indexed 47400 movies (last 20,000 Men a Year)
# Indexed 47500 movies (last Tijuana Jones)
# Indexed 47600 movies (last Random Acts of Christmas)
# Indexed 47700 movies (last First Monday in October)
# Indexed 47800 movies (last Step Up Revolution)
# Indexed 47900 movies (last Mademoiselle Fifi)
# Indexed 48000 movies (last Hack-O-Lantern)
# Indexed 48100 movies (last The White Raven)
# Indexed 48200 movies (last Assholes)
# Indexed 48300 movies (last A Very Nutty Christmas)
# Indexed 48400 movies (last The Gentlemen)
# Indexed 48500 movies (last Ghost Exchange)
# Indexed 48600 movies (last Manifesto)
# Indexed 48700 movies (last A Step from Heaven)
# Indexed 48800 movies (last White Fang)
# Indexed 48900 movies (last First Kid)
# Indexed 49000 movies (last Homeboy)
# Indexed 49100 movies (last Nikki Glaser: Perfect)
# Indexed 49200 movies (last Welcome to Willits)
# Indexed 49300 movies (last Landmarq: Turbulence - Live In Poland)
# Indexed 49400 movies (last Pet Shop)
# Indexed 49500 movies (last The Seduction of Misty Mundae)
# Indexed 49600 movies (last The Russian German War)
# Indexed 49700 movies (last Hard to Handle)
# Indexed 49800 movies (last Money for Nothing: Inside the Federal Reserve)
# Indexed 49900 movies (last Laughing Matters)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 50000 movies (last Not Wanted on Voyage)
# Indexed 50100 movies (last Rocky)
# Indexed 50200 movies (last I ♥ Huckabees)
# Indexed 50300 movies (last A Chorus Line)
# Indexed 50400 movies (last Bra Boys)
# Indexed 50500 movies (last The Stewardesses)
# Indexed 50600 movies (last McDick)
# Indexed 50700 movies (last The Conspirator)
# Indexed 50800 movies (last Bikini Airways)
# Indexed 50900 movies (last Panodrama)
# Indexed 51000 movies (last House of Flying Arrows)
# Indexed 51100 movies (last Jose Canseco: The Truth Hurts)
# Indexed 51200 movies (last Angry Video Game Nerd: The Movie)
# Indexed 51300 movies (last Private's Progress)
# Indexed 51400 movies (last Me and My Gal)
# Indexed 51500 movies (last The Large Rope)
# Indexed 51600 movies (last Never Goin' Back)
# Indexed 51700 movies (last El Karmooty in the Land of Fire)
# Indexed 51800 movies (last The Settlers)
# Indexed 51900 movies (last Retina)
# Indexed 52000 movies (last Life Is But a Dream)
# Indexed 52100 movies (last Louis Theroux: Selling Sex)
# Indexed 52200 movies (last The Bells Go Down)
# Indexed 52300 movies (last Miracles For Sale)
# Indexed 52400 movies (last In Bruges)
# Indexed 52500 movies (last Christine)
# Indexed 52600 movies (last La bañera)
# Indexed 52700 movies (last Freaky Friday)
# Indexed 52800 movies (last The Earthling)
# Indexed 52900 movies (last Criminal Desires)
# Indexed 53000 movies (last The Ambulance)
# Indexed 53100 movies (last The Driftless Area)
# Indexed 53200 movies (last The Human Race)
# Indexed 53300 movies (last Goosebumps: The Headless Ghost)
# Indexed 53400 movies (last Times Square Lady)
# Indexed 53500 movies (last Mayday Life)
# Indexed 53600 movies (last Captive Hearts)
# Indexed 53700 movies (last Escape Velocity)
# Indexed 53800 movies (last The Man in the Net)
# Indexed 53900 movies (last Chickenfoot: Get Your Buzz On)
# Indexed 54000 movies (last Porcupine Tree: In Absentia DVD-A)
# Indexed 54100 movies (last Sand)
# Indexed 54200 movies (last Hero)
# Indexed 54300 movies (last Secrets In The Snow)
# Indexed 54400 movies (last Going for Broke)
# Indexed 54500 movies (last WWE: ECW - Unreleased Vol. 1)
# Indexed 54600 movies (last The Advocate for Fagdom)
# Indexed 54700 movies (last Furthest Witness)
# Indexed 54800 movies (last The Indigo Evolution)
# Indexed 54900 movies (last Night Comes On)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 55000 movies (last Spaced Invaders)
# Indexed 55100 movies (last The Descent: Part 2)
# Indexed 55200 movies (last The Back-Up Plan)
# Indexed 55300 movies (last The Rebound)
# Indexed 55400 movies (last Fish Tank)
# Indexed 55500 movies (last Going Berserk)
# Indexed 55600 movies (last The Escape from Auschwitz)
# Indexed 55700 movies (last Three Colors: Red)
# Indexed 55800 movies (last Three Wishes for Cinderella)
# Indexed 55900 movies (last They Call Me Trinity)
# Indexed 56000 movies (last Om Shanti Om)
# Indexed 56100 movies (last Ida)
# Indexed 56200 movies (last Quo vado?)
# Indexed 56300 movies (last Dragon Hunters)
# Indexed 56400 movies (last Young & Beautiful)
# Indexed 56500 movies (last The New Girlfriend)
# Indexed 56600 movies (last Le Crocodile du Botswanga)
# Indexed 56700 movies (last The Monk)
# Indexed 56800 movies (last Tinpis Run)
# Indexed 56900 movies (last The Promise)
# Indexed 57000 movies (last Titanic)
# Indexed 57100 movies (last Fall from Grace)
# Indexed 57200 movies (last Danton)
# Indexed 57300 movies (last Gamera vs. Jiger)
# Indexed 57400 movies (last The Million Game)
# Indexed 57500 movies (last Cruel Gun Story)
# Indexed 57600 movies (last Nostalgia for the Light)
# Indexed 57700 movies (last The Little Polar Bear: Lars and the Little Tiger)
# Indexed 57800 movies (last Hamlet Goes Business)
# Indexed 57900 movies (last Feast of All Saints)
# Indexed 58000 movies (last Jekyll + Hyde)
# Indexed 58100 movies (last The Best Man's Wedding)
# Indexed 58200 movies (last Münchhausen)
# Indexed 58300 movies (last Flight of the Red Balloon)
# Indexed 58400 movies (last Days and Clouds)
# Indexed 58500 movies (last Children of Glory)
# Indexed 58600 movies (last The Odds)
# Indexed 58700 movies (last Beloved/Friend)
# Indexed 58800 movies (last Sex Up Your Life!)
# Indexed 58900 movies (last Kisses For My President)
# Indexed 59000 movies (last After You)
# Indexed 59100 movies (last The Gamers: Hands of Fate)
# Indexed 59200 movies (last People of the Wind)
# Indexed 59300 movies (last Faust)
# Indexed 59400 movies (last Autism: The Musical)
# Indexed 59500 movies (last Cookers)
# Indexed 59600 movies (last The White Sun of the Desert)
# Indexed 59700 movies (last Moliere)
# Indexed 59800 movies (last Good Copy Bad Copy)
# Indexed 59900 movies (last Bandit Queen)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 60000 movies (last Bela Kiss: Prologue)
# Indexed 60100 movies (last Space)
# Indexed 60200 movies (last Throw Down)
# Indexed 60300 movies (last I am Von Höfler Variation on Werther)
# Indexed 60400 movies (last Children of Nature)
# Indexed 60500 movies (last Mei and the Kittenbus)
# Indexed 60600 movies (last The Overcoat)
# Indexed 60700 movies (last The Art of Crying)
# Indexed 60800 movies (last Hanussen)
# Indexed 60900 movies (last Chance Pe Dance)
# Indexed 61000 movies (last Under the Sun of Satan)
# Indexed 61100 movies (last Made in Britain)
# Indexed 61200 movies (last Scandal)
# Indexed 61300 movies (last Goofy Movies Number One)
# Indexed 61400 movies (last The Human Condition II: Road to Eternity)
# Indexed 61500 movies (last Crows and Sparrows)
# Indexed 61600 movies (last The Noose)
# Indexed 61700 movies (last Ill Gotten Gains)
# Indexed 61800 movies (last Asier ETA biok)
# Indexed 61900 movies (last Murder by Proxy:  How America Went Postal)
# Indexed 62000 movies (last Number One with a Bullet)
# Indexed 62100 movies (last The Body)
# Indexed 62200 movies (last Late Night Trains)
# Indexed 62300 movies (last The Streetfighter)
# Indexed 62400 movies (last The Human Behavior Experiments)
# Indexed 62500 movies (last Family)
# Indexed 62600 movies (last Women in Love)
# Indexed 62700 movies (last The Life of Oharu)
# Indexed 62800 movies (last Vagabond)
# Indexed 62900 movies (last The Wild Hunt)
# Indexed 63000 movies (last Comme les 5 doigts de la main)
# Indexed 63100 movies (last The 36 Crazy Fists)
# Indexed 63200 movies (last Behind Blue Skies)
# Indexed 63300 movies (last The Bottom of the Sea)
# Indexed 63400 movies (last La Soufrière)
# Indexed 63500 movies (last Black Heaven)
# Indexed 63600 movies (last The Mystery of the Third Planet)
# Indexed 63700 movies (last Yu-Gi-Oh!)
# Indexed 63800 movies (last The Electric House)
# Indexed 63900 movies (last Antboy: Revenge of the Red Fury)
# Indexed 64000 movies (last Adult Camp)
# Indexed 64100 movies (last Face)
# Indexed 64200 movies (last Adventures of Zatôichi)
# Indexed 64300 movies (last Santo vs. the She-Wolves)
# Indexed 64400 movies (last Ossos)
# Indexed 64500 movies (last Paz!)
# Indexed 64600 movies (last All the Way Home)
# Indexed 64700 movies (last May 18)
# Indexed 64800 movies (last Carmen Miranda: Bananas Is My Business)
# Indexed 64900 movies (last Among Wolves)
# Flushing 5000 docs
# Done [Status: 200]
# Indexed 65000 movies (last This So-Called Disaster: Sam Shepard Directs "The Late Henry Moss")
# Indexed 65100 movies (last Please Remove Your Shoes)
# Indexed 65200 movies (last The Newest Pledge)
# Indexed 65300 movies (last Very Annie Mary)
# Indexed 65400 movies (last The Childhood of Maxim Gorky)
# Indexed 65500 movies (last Quinceañera)
# Indexed 65600 movies (last Love and Anarchy)
# Flushing 616 docs
# Done [Status: 200]
# Committed index tmdb [Status: 200]
# Done

# %% [markdown]
# ## Listing 1, View Doc

# %%
client.get_doc(index='tmdb', doc_id='37799', fields=['title','tagline','overview','release_year'])
# Out:
# {'title': ['The Social Network'],
#  'overview': ['On a fall night in 2003, Harvard undergrad and computer programming genius Mark Zuckerberg sits down at his computer and heatedly begins working on a new idea. In a fury of blogging and programming, what begins in his dorm room as a small site among friends soon becomes a global social network and a revolution in communication. A mere six years and 500 million friends later, Mark Zuckerberg is the youngest billionaire in history... but for this entrepreneur, success leads to both personal and legal complications.'],
#  'tagline': ["You don't get to 500 million friends without making a few enemies."],
#  'release_year': 2010}

# %% [markdown]
# ## Manual boosting
#
# One 'generalizable' relevance solution that gets at the long tail is a manually derivved relevance function

# %%
q="""title:({keywords})^10
     overview:({keywords})^20
     {{!func}}release_year^0.01"""

q = q.format(keywords='mark zuckerberg college')

solr_q = {'defType': 'edismax',
          'fl': 'title ',
          'q': q}

client.query(index='tmdb', query=solr_q)
# Out:
# [{'title': ['The Social Network']},
#  {'title': ['Waxwork']},
#  {'title': ['Mark Twain']},
#  {'title': ['College Girls']},
#  {'title': ['College']},
#  {'title': ['Six: The Mark Unleashed']},
#  {'title': ['Mark Shoots First']},
#  {'title': ['College Swing']},
#  {'title': ['The Adventures of Mark Twain']},
#  {'title': ['College Humor']}]

# %%
q="""title:({keywords})^{ti_bm25_weight}
     overview:({keywords})^{ov_bm25_weight}
     {{!func}}release_year^{release_year_weight}"""

q = q.format(ti_bm25_weight=10,
             ov_bm25_weight=20,
             release_year_weight=0.01,
             keywords='mark zuckerberg college')

solr_q = {'defType': 'edismax',
          'fl': 'title',
          'q': q}

client.query(index='tmdb', query=solr_q)
# Out:
# [{'title': ['The Social Network']},
#  {'title': ['Waxwork']},
#  {'title': ['Mark Twain']},
#  {'title': ['College Girls']},
#  {'title': ['College']},
#  {'title': ['Six: The Mark Unleashed']},
#  {'title': ['Mark Shoots First']},
#  {'title': ['College Swing']},
#  {'title': ['The Adventures of Mark Twain']},
#  {'title': ['College Humor']}]

# %%
def judg_csv(judgment):
    from ltr.helpers.movies import get_movie
    judgedMovie = get_movie(movies='data/tmdb_ai_pow_search.json', tmdb_id=judgment.docId)
    return "{grade},'{title}',{keywords}".format(grade=judgment.grade,
                                                 title=judgedMovie['title'],
                                                 keywords=judgment.keywords)

# Make a baby judgment list for book display
from ltr.judgments import judgments_from_file
to_sample={11:[0,1,6,9], # qid->rows in qid to sample
           40:[0,5,12,7,20]}

mini_judg_list=[]

from itertools import groupby
judgment_dict={}
new_qid=1
with open('data/title_judgments_binary.txt') as f:
    for qid, query_judgments in groupby(judgments_from_file(f), key=lambda j: j.qid):
        if qid in to_sample.keys():
            query_judgments = [j for j in query_judgments]
            for row in to_sample[qid]:
                query_judgments[row].qid=new_qid
                mini_judg_list.append(query_judgments[row])
            new_qid+=1

mini_judg_list
# Out:
# Recognizing 65 queries...
# [Judgment(grade=1,qid=1,keywords=social network,docId=37799,features=[],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=267752,features=[],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=38408,features=[],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=28303,features=[],weight=1,
#  Judgment(grade=1,qid=2,keywords=star wars,docId=11,features=[],weight=1,
#  Judgment(grade=1,qid=2,keywords=star wars,docId=1892,features=[],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=54138,features=[],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=85783,features=[],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=325553,features=[],weight=1]

# %%
def judg_csv(judgment):
    judgedMovie = get_movie(movies='data/tmdb_ai_pow_search.json', tmdb_id=judgment.docId)
    return "{grade},'{title}',{keywords}".format(grade=judgment.grade,
                                                 title=judgedMovie['title'],
                                                 keywords=judgment.keywords)

# %% [markdown]
# ### As CSV

# %%
for judgment in mini_judg_list:
    print(judg_csv(judgment))
# Out:
# 1,'The Social Network',social network
# 0,'#chicagoGirl',social network
# 0,'Life As We Know It',social network
# 0,'The Cheyenne Social Club',social network
# 1,'Star Wars',star wars
# 1,'Return of the Jedi',star wars
# 0,'Star Trek Into Darkness',star wars
# 0,'The Star',star wars
# 0,'Battlestar Galactica',star wars

# %% [markdown]
# ### Dump the file...

# %%
from ltr.judgments import judgments_to_file
from io import StringIO

string_f = StringIO()
judgments_to_file(string_f, judgmentsList=mini_judg_list)

print(string_f.getvalue())
# Out:
# # qid:1: social network*1
# # qid:2: star wars*1
#
# 1	qid:1	 # 37799	social network
# 0	qid:1	 # 267752	social network
# 0	qid:1	 # 38408	social network
# 0	qid:1	 # 28303	social network
# 1	qid:2	 # 11	star wars
# 1	qid:2	 # 1892	star wars
# 0	qid:2	 # 54138	star wars
# 0	qid:2	 # 85783	star wars
# 0	qid:2	 # 325553	star wars

# %% [markdown]
# ### Same plausible features on each

# %%
# Setup some features for this dummy dataset
client.reset_ltr(index='tmdb')

ftr_config = [
    #1
    {
      "name" : "title_bm25",
      "store": "dummy",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:(${keywords})"
      }
    },
    #2
    {
      "name" : "overview_bm25",
      "store": "dummy",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:(${keywords})"
      }
    },
    {#3
      "name" : "release_year",
      "store": "dummy",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!func}def(release_year,2000)"
      }
    }

]


judgments_string=string_f.getvalue()
client.create_featureset(index='tmdb', name='dummy', ftr_config=ftr_config)

from ltr.judgments import judgments_reader
from ltr.log import FeatureLogger

ftr_logger=FeatureLogger(client, index='tmdb', feature_set='dummy')
with judgments_reader(StringIO(judgments_string)) as judgments:
    for qid, query_judgments in groupby(judgments, key=lambda j: j.qid):
        ftr_logger.log_for_qid(qid=qid,
                               keywords=judgments.keywords(qid),
                               judgments=query_judgments)
# Out:
# Deleted dummy Featurestore [Status: 200]
# Deleted movie Featurestore [Status: 200]
# Deleted test Featurestore [Status: 200]
# Created dummy feature store under tmdb: [Status: 200]
# Recognizing 2 queries...
# Searching tmdb [Status: 200]
# Discarded 0 Keep 4
# Searching tmdb [Status: 200]
# Discarded 0 Keep 5

# %% [markdown]
# ## Dump the training set

# %%
from ltr.judgments import judgments_writer
from io import StringIO

string_f = StringIO()
with judgments_writer(string_f) as writer:
    for j in ftr_logger.logged:
        writer.write(j)

print(string_f.getvalue())
# Out:
# # qid:1: social network*1
# # qid:2: star wars*1
#
# 1	qid:1	1:18.135925	2:8.391596	3:2010.0 # 37799	social network
# 0	qid:1	1:0.0	2:13.237938	3:2013.0 # 267752	social network
# 0	qid:1	1:0.0	2:9.576859	3:2010.0 # 38408	social network
# 0	qid:1	1:7.5430527	2:6.839079	3:1970.0 # 28303	social network
# 1	qid:2	1:14.951998	2:0.0	3:1977.0 # 11	star wars
# 1	qid:2	1:0.0	2:4.3300323	3:1983.0 # 1892	star wars
# 0	qid:2	1:5.377082	2:0.0	3:2013.0 # 54138	star wars
# 0	qid:2	1:7.01165	2:0.0	3:1952.0 # 85783	star wars
# 0	qid:2	1:0.0	2:0.0	3:2003.0 # 325553	star wars

# %%
import requests

feature_set = [
    {
      "name" : "title_bm25",
      "store": "movie",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : { #q=title:({$keywords})
        "q" : "title:(${keywords})"
      }
    },
    {
      "name" : "overview_bm25",
      "store": "movie",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:(${keywords})"
      }
    },
    {
      "name" : "vote_average",
      "store": "movie",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!func}vote_average"
      }
    }
   
]

requests.put('http://localhost:8983/solr/tmdb/schema/feature-store',
             json=feature_set)
# Out:
# <Response [200]>

# %%
logging_solr_query = {
    "fl": "id,title,[features store=movie efi.keywords=\"social network\"]",
    'q': "id:37799 OR id:267752 id:38408 OR id:28303", #social network graded documents
    'rows': 10,
    'wt': 'json'  
}

resp = requests.post('http://localhost:8983/solr/tmdb/select',
                     data=logging_solr_query)
resp.json()
# Out:
# {'responseHeader': {'status': 0,
#   'QTime': 1,
#   'params': {'q': 'id:37799 OR id:267752 id:38408 OR id:28303',
#    'fl': 'id,title,[features store=movie efi.keywords="social network"]',
#    'rows': '10',
#    'wt': 'json'}},
#  'response': {'numFound': 4,
#   'start': 0,
#   'docs': [{'id': '38408',
#     'title': ['Life As We Know It'],
#     '[features]': 'title_bm25=0.0,overview_bm25=9.576859,vote_average=6.8'},
#    {'id': '28303',
#     'title': ['The Cheyenne Social Club'],
#     '[features]': 'title_bm25=7.5430527,overview_bm25=6.839079,vote_average=6.4'},
#    {'id': '37799',
#     'title': ['The Social Network'],
#     '[features]': 'title_bm25=18.135925,overview_bm25=8.391596,vote_average=7.3'},
#    {'id': '267752',
#     'title': ['#chicagoGirl'],
#     '[features]': 'title_bm25=0.0,overview_bm25=13.237938,vote_average=7.0'}]}}

# %%
from ltr.client.solr_client import SolrClient

client = SolrClient(host='http://localhost:8983/solr')

# %%
from ltr.judgments import Judgment

Judgment(qid=1,keywords='social network',doc_id=37799,grade=1)
# Out:
# Judgment(grade=1,qid=1,keywords=social network,doc_id=37799,features=[],weight=1

# %% [markdown]
# ```
# 1	qid:1	1:18.135925	2:8.391596	3:2010.0 # 37799	social network
# 0	qid:1	1:0.0	2:13.237938	3:2013.0 # 267752	social network
# 0	qid:1	1:0.0	2:9.576859	3:2010.0 # 38408	social network
# 0	qid:1	1:7.5430527	2:6.839079	3:1970.0 # 28303	social network
# 1	qid:2	1:14.951998	2:0.0	3:1977.0 # 11	star wars
# 1	qid:2	1:0.0	2:4.3300323	3:1983.0 # 1892	star wars
# 0	qid:2	1:5.377082	2:0.0	3:2013.0 # 54138	star wars
# 0	qid:2	1:7.01165	2:0.0	3:1952.0 # 85783	star wars
# 0	qid:2	1:0.0	2:0.0	3:2003.0 # 325553	star wars
# ```

# %%
mini_judg_list=[
    Judgment(grade=1, qid=1, keywords='social network', doc_id=37799),
    Judgment(grade=0, qid=1, keywords='social network', doc_id=267752),
    Judgment(grade=0, qid=1, keywords='social network', doc_id=38408),
    Judgment(grade=0, qid=1, keywords='social network', doc_id=28303),
    Judgment(grade=1, qid=2, keywords='star wars', doc_id=11),
    Judgment(grade=1, qid=2, keywords='star wars', doc_id=1892),
    Judgment(grade=0, qid=2, keywords='star wars', doc_id=54138),
    Judgment(grade=0, qid=2, keywords='star wars', doc_id=85783),
    Judgment(grade=0, qid=2, keywords='star wars', doc_id=325553),    
]

from ltr.judgments import judgments_writer
from io import StringIO

string_file = StringIO()
with judgments_writer(string_file) as writer:
    for j in mini_judg_list:
        writer.write(j)

print(string_f.getvalue())
# Out:
# # qid:1: social network*1
# # qid:2: star wars*1
#
# 1	qid:1	 # 37799	social network
# 0	qid:1	 # 267752	social network
# 0	qid:1	 # 38408	social network
# 0	qid:1	 # 28303	social network
# 1	qid:2	 # 11	star wars
# 1	qid:2	 # 1892	star wars
# 0	qid:2	 # 54138	star wars
# 0	qid:2	 # 85783	star wars
# 0	qid:2	 # 325553	star wars

# %%
mini_judg_list[0].features
# Out:
# []

# %%
from ltr.log import FeatureLogger
from ltr.judgments import judgments_open
from itertools import groupby

ftr_logger=FeatureLogger(client, index='tmdb', feature_set='movie')
for qid, query_judgments in groupby(mini_judg_list, key=lambda j: j.qid):
    ftr_logger.log_for_qid(judgments=query_judgments, 
                           qid=qid)
        
ftr_logger.logged
# Out:
# Searching tmdb [Status: 200]
# Discarded 0 Keep 4
# Searching tmdb [Status: 200]
# Discarded 0 Keep 5
# [Judgment(grade=1,qid=1,keywords=social network,docId=37799,features=[18.135925, 8.391596, 7.3],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=267752,features=[0.0, 13.237938, 7.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=38408,features=[0.0, 9.576859, 6.8],weight=1,
#  Judgment(grade=0,qid=1,keywords=social network,docId=28303,features=[7.5430527, 6.839079, 6.4],weight=1,
#  Judgment(grade=1,qid=2,keywords=star wars,docId=11,features=[14.951998, 0.0, 8.2],weight=1,
#  Judgment(grade=1,qid=2,keywords=star wars,docId=1892,features=[0.0, 4.3300323, 8.0],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=54138,features=[5.377082, 0.0, 7.3],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=85783,features=[7.01165, 0.0, 7.5],weight=1,
#  Judgment(grade=0,qid=2,keywords=star wars,docId=325553,features=[0.0, 0.0, 8.1],weight=1]

# %%
from ltr import download
from ltr.log import FeatureLogger
from ltr.judgments import judgments_open
from itertools import groupby

judgments='http://es-learn-to-rank.labs.o19s.com/title_judgments_binary.txt'
download([judgments], dest='data/')

ftr_logger=FeatureLogger(client, index='tmdb', feature_set='movie')

with judgments_open('data/title_judgments.txt') as judgment_list:
    for qid, query_judgments in groupby(judgment_list, key=lambda j: j.qid):
        ftr_logger.log_for_qid(judgments=query_judgments, 
                               qid=qid,
                               keywords=judgment_list.keywords(qid))
        
ftr_logger.logged
# Out:
# data/title_judgments_binary.txt already exists
# Recognizing 40 queries...
# Searching tmdb [Status: 200]
# Discarded 0 Keep 41
# Searching tmdb [Status: 200]
# Discarded 0 Keep 41
# Searching tmdb [Status: 200]
# Discarded 0 Keep 39
# Searching tmdb [Status: 200]
# Discarded 0 Keep 28
# Searching tmdb [Status: 200]
# Discarded 0 Keep 33
# Searching tmdb [Status: 200]
# Discarded 0 Keep 39
# Searching tmdb [Status: 200]
# Discarded 0 Keep 35
# Searching tmdb [Status: 200]
# Discarded 0 Keep 38
# Searching tmdb [Status: 200]
# Discarded 0 Keep 35
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 28
# Searching tmdb [Status: 200]
# Discarded 0 Keep 34
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 30
# Searching tmdb [Status: 200]
# Discarded 0 Keep 35
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 35
# Searching tmdb [Status: 200]
# Discarded 0 Keep 32
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 30
# Searching tmdb [Status: 200]
# Discarded 0 Keep 44
# Searching tmdb [Status: 200]
# Discarded 0 Keep 34
# Searching tmdb [Status: 200]
# Discarded 0 Keep 35
# Searching tmdb [Status: 200]
# Discarded 0 Keep 33
# Searching tmdb [Status: 200]
# Discarded 0 Keep 38
# Searching tmdb [Status: 200]
# Discarded 0 Keep 38
# Searching tmdb [Status: 200]
# Discarded 0 Keep 40
# Searching tmdb [Status: 200]
# Discarded 0 Keep 40
# Searching tmdb [Status: 200]
# Discarded 0 Keep 30
# Searching tmdb [Status: 200]
# Discarded 0 Keep 41
# Searching tmdb [Status: 200]
# Discarded 0 Keep 28
# Searching tmdb [Status: 200]
# Discarded 0 Keep 41
# Searching tmdb [Status: 200]
# Discarded 0 Keep 39
# Searching tmdb [Status: 200]
# Discarded 0 Keep 36
# Searching tmdb [Status: 200]
# Discarded 0 Keep 31
# Searching tmdb [Status: 200]
# Discarded 0 Keep 36
# Searching tmdb [Status: 200]
# Discarded 0 Keep 36
# Searching tmdb [Status: 200]
# Discarded 0 Keep 32
# Searching tmdb [Status: 200]
# Discarded 0 Keep 30
# [Judgment(grade=4,qid=1,keywords=rambo,docId=7555,features=[13.038148, 11.173398, 6.5],weight=1,
#  Judgment(grade=3,qid=1,keywords=rambo,docId=1370,features=[11.056428, 12.652582, 6.0],weight=1,
#  Judgment(grade=3,qid=1,keywords=rambo,docId=1369,features=[7.593794, 10.758981, 6.5],weight=1,
#  Judgment(grade=2,qid=1,keywords=rambo,docId=13258,features=[0.0, 10.096009, 6.7],weight=1,
#  Judgment(grade=4,qid=1,keywords=rambo,docId=1368,features=[0.0, 11.867074, 7.4],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=31362,features=[0.0, 8.33506, 6.0],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=61410,features=[0.0, 4.6697874, 6.9],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=319074,features=[0.0, 0.0, 6.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=10296,features=[0.0, 0.0, 6.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=35868,features=[0.0, 0.0, 5.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=131457,features=[0.0, 0.0, 6.3],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=94794,features=[0.0, 0.0, 7.1],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=169869,features=[0.0, 0.0, 4.3],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=34561,features=[0.0, 0.0, 7.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=13763,features=[0.0, 0.0, 6.7],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=62414,features=[0.0, 0.0, 8.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=21989,features=[0.0, 0.0, 4.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=210577,features=[0.0, 0.0, 7.9],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=56949,features=[0.0, 0.0, 5.8],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=79401,features=[0.0, 0.0, 6.6],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=117942,features=[0.0, 0.0, 3.8],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=223195,features=[0.0, 0.0, 0.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=70,features=[0.0, 0.0, 7.9],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=22777,features=[0.0, 0.0, 5.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=43189,features=[0.0, 0.0, 6.0],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=318,features=[0.0, 0.0, 6.1],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=39829,features=[0.0, 0.0, 6.4],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=208982,features=[0.0, 0.0, 8.3],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=250761,features=[0.0, 0.0, 7.6],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=801,features=[0.0, 0.0, 7.4],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=78999,features=[0.0, 0.0, 7.0],weight=1,
#  Judgment(grade=1,qid=1,keywords=rambo,docId=600,features=[0.0, 0.0, 8.1],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=26397,features=[0.0, 0.0, 9.1],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=45046,features=[0.0, 0.0, 6.2],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=271110,features=[0.0, 0.0, 7.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=59401,features=[0.0, 0.0, 6.6],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=79773,features=[0.0, 0.0, 8.2],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=321,features=[0.0, 0.0, 6.1],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=11553,features=[0.0, 0.0, 7.4],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=32221,features=[0.0, 0.0, 6.6],weight=1,
#  Judgment(grade=0,qid=1,keywords=rambo,docId=40082,features=[0.0, 0.0, 6.2],weight=1,
#  Judgment(grade=4,qid=2,keywords=rocky,docId=1366,features=[11.020994, 8.675259, 7.7],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=1374,features=[9.345869, 7.304178, 6.9],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=1371,features=[9.345869, 6.402419, 6.8],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=1246,features=[9.345869, 9.8396015, 6.7],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=1375,features=[9.345869, 7.177807, 5.6],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=1367,features=[9.345869, 8.083639, 7.1],weight=1,
#  Judgment(grade=3,qid=2,keywords=rocky,docId=60375,features=[9.345869, 7.929142, 5.8],weight=1,
#  Judgment(grade=1,qid=2,keywords=rocky,docId=110123,features=[7.167144, 0.0, 0.0],weight=1,
#  Judgment(grade=1,qid=2,keywords=rocky,docId
0],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=25058,features=[0.0, 0.0, 0.0],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=909,features=[0.0, 0.0, 7.1],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=24197,features=[0.0, 0.0, 6.2],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=787,features=[0.0, 0.0, 6.6],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=3080,features=[0.0, 0.0, 7.7],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=99875,features=[0.0, 0.0, 6.0],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=10588,features=[0.0, 0.0, 5.1],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=43580,features=[0.0, 0.0, 6.6],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=20239,features=[0.0, 0.0, 6.5],weight=1,
#  Judgment(grade=1,qid=28,keywords=kill bill,docId=25602,features=[0.0, 0.0, 5.8],weight=1,
#  Judgment(grade=1,qid=28,keywords=kill bill,docId=48707,features=[0.0, 0.0, 6.3],weight=1,
#  Judgment(grade=1,qid=28,keywords=kill bill,docId=22484,features=[0.0, 0.0, 5.1],weight=1,
#  Judgment(grade=1,qid=28,keywords=kill bill,docId=12500,features=[0.0, 0.0, 5.6],weight=1,
#  Judgment(grade=1,qid=28,keywords=kill bill,docId=52009,features=[0.0, 0.0, 4.5],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=79118,features=[0.0, 0.0, 7.4],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=15669,features=[0.0, 0.0, 5.7],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=47448,features=[0.0, 0.0, 5.0],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=76960,features=[0.0, 0.0, 0.0],weight=1,
#  Judgment(grade=0,qid=28,keywords=kill bill,docId=293461,features=[0.0, 0.0, 0.0],weight=1,
#  Judgment(grade=4,qid=29,keywords=the godfather,docId=238,features=[11.201132, 0.2893359, 8.7],weight=1,
#  Judgment(grade=3,qid=29,keywords=the godfather,docId=242,features=[8.589905, 0.21344505, 7.4],weight=1,
#  Judgment(grade=3,qid=29,keywords=the godfather,docId=240,features=[8.589905, 0.32225084, 8.6],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=77403,features=[9.762411, 9.326275, 6.0],weight=1,
#  Judgment(grade=2,qid=29,keywords=the godfather,docId=70829,features=[9.723254, 0.307983, 4.2],weight=1,
#  Judgment(grade=1,qid=29,keywords=the godfather,docId=18973,features=[0.0, 6.149778, 6.7],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=154779,features=[0.9881444, 7.768722, 5.5],weight=1,
#  Judgment(grade=2,qid=29,keywords=the godfather,docId=45485,features=[0.0, 10.553486, 7.4],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=49852,features=[1.4387205, 9.974427, 5.3],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=54102,features=[0.0, 0.283085, 7.8],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=13533,features=[0.0, 7.3247995, 6.5],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=8995,features=[0.0, 9.838995, 6.6],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=29887,features=[0.0, 9.497632, 6.5],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=62836,features=[1.4387205, 5.249546, 5.5],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=36909,features=[0.0, 4.709856, 5.8],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=82866,features=[0.0, 5.4417963, 0.0],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=75579,features=[0.0, 5.021742, 6.5],weight=1,
#  Judgment(grade=1,qid=29,keywords=the godfather,docId=400,features=[0.0, 8.691921, 6.6],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=21469,features=[1.2488956, 0.0, 5.9],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=1374,features=[0.0, 0.20968719, 6.9],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=12112,features=[0.0, 0.32478, 7.0],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=9469,features=[0.0, 0.0, 6.8],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=27511,features=[0.0, 0.19272201, 7.4],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=279690,features=[0.0, 0.0, 6.1],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=31556,features=[0.0, 0.23445368, 6.7],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=603,features=[1.4387205, 0.34188652, 8.1],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=605,features=[1.2488956, 0.34287077, 6.6],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=604,features=[1.2488956, 0.33163023, 6.9],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=10999,features=[0.0, 0.2579978, 6.6],weight=1,
#  Judgment(grade=0,qid=29,keywords=the godfather,docId=957,features=[0.0, 0.33079365, 6.8],weight=1,
#  ...]
